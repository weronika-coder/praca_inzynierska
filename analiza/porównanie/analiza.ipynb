# %%
#porównanie po O2-Ar, Ar i H2O2
from funkcje.Lorentz2Raman import *

# %%
time9=[0,30,60,90,120,150,180,210,240,270,300]
intensity_PL_mean_9=[np.float64(1023.0732711307471), np.float64(2241.97795990505), np.float64(3234.5048043353268), np.float64(4206.33912673248), np.float64(5885.793406699254), np.float64(6328.396251549986), np.float64(7189.577502058425), np.float64(7911.0495979843645), np.float64(9043.177871980497), np.float64(8551.555922006091), np.float64(7737.747398946359)]

# %%
time1= [0,2,4,6,8]
intensity_PL_mean_1=[np.float64(630.6229394167462), np.float64(1580.9241180337485), np.float64(1172.656893794165), np.float64(277.065191006182), 105.00322778302734]

# %%
time8= [0,2,4,6,8,10]
intensity_PL_mean_8=[np.float64(2113.806276128912), np.float64(1567.0516844359906), np.float64(1828.8403081849112), np.float64(1606.6086462572446), np.float64(1213.0724802497764), np.float64(718.9958546871947)]

# %%
BASE = Path().resolve()
sciezka= BASE / "analiza" / "porównanie"
plt.plot(time1,intensity_PL_mean_1,marker='o',linestyle='--',label=r"O$_2$-Ar plasma")
plt.plot(time8,intensity_PL_mean_8,marker='o',linestyle='--',label="Ar plasma")
#plt.scatter(time9,intensity_PL_mean_9,label=r"H$_2$O$_2$")
plt.legend()
plt.xlabel(r"t (s)")
plt.ylabel("Mean instensity (a.u)")
plt.savefig(sciezka/'zaleznosc_I_PL_od_t.png')

# %%
BASE = Path().resolve()
sciezka= BASE / "analiza" / "porównanie"
plt.plot(time9,intensity_PL_mean_9,marker='o',linestyle='--',color='green',label=r"H$_2$O$_2$")
plt.legend()
plt.xlabel(r"t (s)")
plt.ylabel("Mean instensity (a.u)")
plt.savefig(sciezka/'zaleznosc_I_PL_od_t_H2O2.png')
