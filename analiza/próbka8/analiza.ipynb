# %%
#próbka po plazmie argonowej
from funkcje.Lorentz2Raman import *

# %%
#import wszystkich mapek dla próbki 8
BASE = Path().resolve()
sciezka = BASE / "analiza" / "próbka8" / "dane_pomiarowe"

rs_PL_0s, I_PL_0s = importMap(sciezka/"WSe2_mapa_PL_8_0s.txt")
rs_PL_2s, I_PL_2s = importMap(sciezka/"WSe2_mapa_PL_8_2s.txt")
rs_PL_4s, I_PL_4s = importMap(sciezka/"WSe2_mapa_PL_8_4s.txt")
rs_PL_6s, I_PL_6s = importMap(sciezka/"WSe2_mapa_PL_8_6s.txt")
rs_PL_8s, I_PL_8s = importMap(sciezka/"WSe2_mapa_PL_8_8s.txt")
rs_PL_10s, I_PL_10s = importMap(sciezka/"WSe2_mapa_PL_8_10s.txt")

rs_Raman_0s, I_Raman_0s = importMap(sciezka/"WSe2_mapa_Raman_8_0s.txt")
rs_Raman_2s, I_Raman_2s = importMap(sciezka/"WSe2_mapa_Raman_8_2s.txt")
rs_Raman_4s, I_Raman_4s = importMap(sciezka/"WSe2_mapa_Raman_8_4s.txt")
rs_Raman_6s, I_Raman_6s = importMap(sciezka/"WSe2_mapa_Raman_8_6s.txt")
rs_Raman_8s, I_Raman_8s = importMap(sciezka/"WSe2_mapa_Raman_8_8s.txt")
rs_Raman_10s, I_Raman_10s = importMap(sciezka/"WSe2_mapa_Raman_8_10s.txt")

# %%
#testowe pojedyncze widma PL, żebym wiedziała co dopasować 
plt.plot(rs_PL_0s[12], I_PL_0s[12],label="t=0s")
plt.plot(rs_PL_2s[10], I_PL_2s[12],label="t=2s")
plt.plot(rs_PL_4s[12], I_PL_4s[12],label="t=4s")
plt.plot(rs_PL_6s[10], I_PL_6s[12],label="t=6s")
plt.plot(rs_PL_8s[12], I_PL_8s[12],label="t=8s")
plt.plot(rs_PL_10s[4], I_PL_10s[12],label="t=10s")
plt.xlabel(r"E (eV)")
plt.ylabel("Intensity (a.u.)")
plt.legend()
sciezka = BASE / "analiza" / "próbka8" / "wykresy"
plt.savefig(sciezka/'PL.png')

# %%
# testowe pojedyncze widma ramana, żebym wiedziała co dopasować 
plt.plot(rs_Raman_0s[12], I_Raman_0s[12],label="t=0s")
plt.plot(rs_Raman_2s[12], I_Raman_2s[12],label="t=2s")
plt.plot(rs_Raman_4s[12], I_Raman_4s[12],label="t=4s")
plt.plot(rs_Raman_6s[12], I_Raman_6s[12],label="t=6s")
plt.plot(rs_Raman_8s[12], I_Raman_8s[12],label="t=8s")
plt.plot(rs_Raman_10s[12], I_Raman_10s[12],label="t=10s")
plt.xlabel(r"Ramanshift (cm$^{-1}$)")
plt.ylabel("Intensity (a.u.)")
plt.legend()
#plt.xlim(225,280)

# %%
#dopasowanie PL
centers_PL_0s, fwhms_PL_0s, intensities_PL_0s = lorentz2map(rs_PL_0s, I_PL_0s, xmin=1.5, xmax=1.7)
centers_PL_2s, fwhms_PL_2s, intensities_PL_2s = lorentz2map(rs_PL_2s, I_PL_2s, xmin=1.55, xmax=1.75)
centers_PL_4s, fwhms_PL_4s, intensities_PL_4s = lorentz2map(rs_PL_4s, I_PL_4s, xmin=1.55, xmax=1.75)
centers_PL_6s, fwhms_PL_6s, intensities_PL_6s = lorentz2map(rs_PL_6s, I_PL_6s, xmin=1.55, xmax=1.75)
centers_PL_8s, fwhms_PL_8s, intensities_PL_8s = lorentz2map(rs_PL_8s, I_PL_8s, xmin=1.55, xmax=1.75)
centers_PL_10s, fwhms_PL_10s, intensities_PL_10s = lorentz2map(rs_PL_10s, I_PL_10s, xmin=1.55, xmax=1.75)

# %%
#dopasowanie E
centers_Raman_E_0s, fwhms_Raman_E_0s, intensities_Raman_E_0s = lorentz2map(rs_Raman_0s, I_Raman_0s, xmin=240, xmax=255)
centers_Raman_E_2s, fwhms_Raman_E_2s, intensities_Raman_E_2s = lorentz2map(rs_Raman_2s, I_Raman_2s, xmin=240, xmax=255)
centers_Raman_E_4s, fwhms_Raman_E_4s, intensities_Raman_E_4s = lorentz2map(rs_Raman_4s, I_Raman_4s, xmin=240, xmax=255)
centers_Raman_E_6s, fwhms_Raman_E_6s, intensities_Raman_E_6s = lorentz2map(rs_Raman_6s, I_Raman_6s,xmin=240, xmax=255)
centers_Raman_E_8s, fwhms_Raman_E_8s, intensities_Raman_E_8s = lorentz2map(rs_Raman_8s, I_Raman_8s,xmin=240, xmax=255)
centers_Raman_E_10s, fwhms_Raman_E_10s, intensities_Raman_E_10s = lorentz2map(rs_Raman_10s, I_Raman_10s,xmin=240, xmax=255)

# %%
#dopasowanie A
centers_Raman_A_0s, fwhms_Raman_A_0s, intensities_Raman_A_0s = lorentz2map(rs_Raman_0s, I_Raman_0s, xmin=255, xmax=265)
centers_Raman_A_2s, fwhms_Raman_A_2s, intensities_Raman_A_2s = lorentz2map(rs_Raman_2s, I_Raman_2s, xmin=255, xmax=265)
centers_Raman_A_4s, fwhms_Raman_A_4s, intensities_Raman_A_4s = lorentz2map(rs_Raman_4s, I_Raman_4s, xmin=255, xmax=265)
centers_Raman_A_6s, fwhms_Raman_A_6s, intensities_Raman_A_6s = lorentz2map(rs_Raman_6s, I_Raman_6s,xmin=255, xmax=265)
centers_Raman_A_8s, fwhms_Raman_A_8s, intensities_Raman_A_8s = lorentz2map(rs_Raman_8s, I_Raman_8s,xmin=255, xmax=265)
centers_Raman_A_10s, fwhms_Raman_A_10s, intensities_Raman_A_10s = lorentz2map(rs_Raman_10s, I_Raman_10s,xmin=255, xmax=265)

# %%
print(intensities_PL_2s)
intensities_PL_2s = np.delete(intensities_PL_2s, [14,20])
centers_PL_2s = np.delete(centers_PL_2s, [14,20])
fwhms_PL_2s = np.delete(fwhms_PL_2s, [14,20])
print(intensities_PL_2s)
# Out:
# %%
print(intensities_PL_8s)
intensities_PL_8s = np.delete(intensities_PL_8s,[0,4,20])
print(intensities_PL_8s)
# Out:
# [ 273.22435956 1292.00739648 1205.6914753  1189.76443611  608.76354385
#  1203.16973008 1344.96709032 1195.79500892 1433.67164255 1191.95457228
#  1251.61321741 1318.00479248  755.40901149 1346.36958276 1292.87030887
#   917.70863088 1126.30962253 1221.48387078 1213.04849265 1335.46576261
#   533.37706045]
# [1292.00739648 1205.6914753  1189.76443611 1203.16973008 1344.96709032
#  1195.79500892 1433.67164255 1191.95457228 1251.61321741 1318.00479248
#   755.40901149 1346.36958276 1292.87030887  917.70863088 1126.30962253
#  1221.48387078 1213.04849265 1335.46576261]

# %%
intensity_PL_mean_8=[np.mean(intensities_PL_0s),np.mean(intensities_PL_2s),np.mean(intensities_PL_4s),np.mean(intensities_PL_6s),np.mean(intensities_PL_8s),np.mean(intensities_PL_10s)]
centers_PL_mean_8=[np.mean(centers_PL_0s),np.mean(centers_PL_2s),np.mean(centers_PL_4s),np.mean(centers_PL_6s),np.mean(centers_PL_8s),np.mean(centers_PL_10s)]
fwhms_PL_mean_8=[np.mean(fwhms_PL_0s),np.mean(fwhms_PL_2s),np.mean(fwhms_PL_4s),np.mean(fwhms_PL_6s),np.mean(fwhms_PL_8s),np.mean(fwhms_PL_10s)]

intensity_Raman_E_mean_8=[np.mean(intensities_Raman_E_0s),np.mean(intensities_Raman_E_2s),np.mean(intensities_Raman_E_4s),np.mean(intensities_Raman_E_6s),np.mean(intensities_Raman_E_8s),np.mean(intensities_Raman_E_10s)]
centers_Raman_E_mean_8=[np.mean(centers_Raman_E_0s),np.mean(centers_Raman_E_2s),np.mean(centers_Raman_E_4s),np.mean(centers_Raman_E_6s),np.mean(centers_Raman_E_8s),np.mean(centers_Raman_E_10s)]
fwhms_Raman_E_mean_8=[np.mean(fwhms_Raman_E_0s),np.mean(fwhms_Raman_E_2s),np.mean(fwhms_Raman_E_4s),np.mean(fwhms_Raman_E_6s),np.mean(fwhms_Raman_E_8s),np.mean(fwhms_Raman_E_10s)]

intensity_Raman_A_mean_8=[np.mean(intensities_Raman_A_0s),np.mean(intensities_Raman_A_2s),np.mean(intensities_Raman_A_4s),np.mean(intensities_Raman_A_6s),np.mean(intensities_Raman_A_8s),np.mean(intensities_Raman_A_10s)]
centers_Raman_A_mean_8=[np.mean(centers_Raman_A_0s),np.mean(centers_Raman_A_2s),np.mean(centers_Raman_A_4s),np.mean(centers_Raman_A_6s),np.mean(centers_Raman_A_8s),np.mean(centers_Raman_A_10s)]
fwhms_Raman_A_mean_8=[np.mean(fwhms_Raman_A_0s),np.mean(fwhms_Raman_A_2s),np.mean(fwhms_Raman_A_4s),np.mean(fwhms_Raman_A_6s),np.mean(fwhms_Raman_A_8s),np.mean(fwhms_Raman_A_10s)]

# %%
print(intensity_PL_mean_8)
# Out:
# [np.float64(2113.806276128912), np.float64(1567.0516844359906), np.float64(1828.8403081849112), np.float64(1606.6086462572446), np.float64(1213.0724802497764), np.float64(718.9958546871947)]

# %%
x = np.linspace(1.45,1.85, 500)
times    = [0,2,4,6,8,10]


for t, c, f, h in zip(times, centers_PL_mean_8, fwhms_PL_mean_8, intensity_PL_mean_8):
    #jeśli się nie dopasowało to fit zwraca nan, pozbywamy się ich 
    mask = ~np.isnan(c) & ~np.isnan(f) & ~np.isnan(h)
    c0 = np.mean(np.array(c)[mask])
    f0 = np.mean(np.array(f)[mask])
    h0 = np.mean(np.array(h)[mask])
    y = lorentz(x, h0, c0, f0)
    plt.plot(x, y, label=f"t={t}s")

plt.xlabel("E (eV)")
plt.ylabel("Intensity (a.u.)")
plt.xlim(1.45, 1.85)
plt.legend()
plt.savefig(sciezka/'usrednione_PL.png')

# %%
sciezka = BASE / "analiza" / "próbka8" / "wykresy"
time=[0,2,4,6,8,10]
plt.scatter(time,intensity_PL_mean_8,label="próbka 8")
plt.legend()
plt.xlabel(r"t (s)")
plt.ylabel("Mean instensity (a.u)")
plt.savefig(sciezka/'zaleznosc_I_PL_od_t.png')

# %%
time=[0,2,4,6,8,10]
plt.scatter(time,centers_PL_mean_8,label="próbka 8")
plt.legend()
plt.xlabel(r"t (s)")
plt.ylabel("Mean peak position (eV)")
plt.savefig(sciezka/'zaleznosc_x_PL_od_t.png')
#redshift

# %%
sciezka = BASE / "analiza" / "próbka8" / "wykresy"
time=[0,2,4,6,8,10]
plt.scatter(time,fwhms_PL_mean_8,label="próbka 8")
plt.legend()
plt.xlabel(r"t (s)")
plt.ylabel("Mean FWHM (a.u)")
plt.savefig(sciezka/'zaleznosc_FWHM_PL_od_t.png')

# %%
x = np.linspace(1.45,1.85, 500)
time= [0,2,4,6,8,10]


for t, c, f, h in zip(time, centers_PL_mean_8, fwhms_PL_mean_8, intensity_PL_mean_8):
    #jeśli się nie dopasowało to fit zwraca nan, pozbywamy się ich 
    mask = ~np.isnan(c) & ~np.isnan(f) & ~np.isnan(h)
    c0 = np.mean(np.array(c)[mask])
    f0 = np.mean(np.array(f)[mask])
    h0 = np.mean(np.array(h)[mask])
    y = lorentz(x, h0, c0, f0)
    plt.plot(x, y, label=f"t={t}s")

plt.xlabel("E (eV)")
plt.ylabel("Intensity (a.u.)")
plt.xlim(1.45, 1.85)
plt.legend()
plt.savefig(sciezka/'usrednione_PL.png')

# %%
time=[0,2,4,6,8,10]
plt.scatter(time,intensity_Raman_E_mean_8,label="próbka 8 pik E$^1_{2g}$+A$_{1g}$")
plt.scatter(time,intensity_Raman_A_mean_8,label="próbka 8 pik 2LA(M)")
plt.xlabel(r"t (s)")
plt.ylabel("Mean instensity (a.u)")
plt.legend()
plt.savefig(sciezka/'zaleznosc_I_Raman_A_od_t.png')
