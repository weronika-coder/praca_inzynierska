# %%
#próbka defektowana H2O2
from funkcje.Lorentz2Raman import *

# %%
#import wszystkich mapek dla próbki 9
BASE = Path().resolve()
sciezka = BASE / "analiza" / "próbka9" / "dane_pomiarowe"

rs_PL_0s, I_PL_0s = importMap(sciezka/"WSe2_mapa_PL_9_0s.txt")
rs_PL_30s, I_PL_30s = importMap(sciezka/"WSe2_mapa_PL_9_30s.txt")
rs_PL_60s, I_PL_60s = importMap(sciezka/"WSe2_mapa_PL_9_60s.txt")
rs_PL_90s, I_PL_90s = importMap(sciezka/"WSe2_mapa_PL_9_90s.txt")
rs_PL_120s, I_PL_120s = importMap(sciezka/"WSe2_mapa_PL_9_120s.txt")
rs_PL_150s, I_PL_150s = importMap(sciezka/"WSe2_mapa_PL_9_150s.txt")
rs_PL_180s, I_PL_180s = importMap(sciezka/"WSe2_mapa_PL_9_180s.txt")
rs_PL_210s, I_PL_210s = importMap(sciezka/"WSe2_mapa_PL_9_210s.txt")
rs_PL_240s, I_PL_240s = importMap(sciezka/"WSe2_mapa_PL_9_240s.txt")
rs_PL_270s, I_PL_270s = importMap(sciezka/"WSe2_mapa_PL_9_270s.txt")
rs_PL_300s, I_PL_300s = importMap(sciezka/"WSe2_mapa_PL_9_300s.txt")

rs_Raman_0s, I_Raman_0s = importMap(sciezka/"WSe2_mapa_Raman_9_0s.txt")
rs_Raman_30s, I_Raman_30s = importMap(sciezka/"WSe2_mapa_Raman_9_30s.txt")
rs_Raman_60s, I_Raman_60s = importMap(sciezka/"WSe2_mapa_Raman_9_60s.txt")
rs_Raman_90s, I_Raman_90s = importMap(sciezka/"WSe2_mapa_Raman_9_90s.txt")
rs_Raman_120s, I_Raman_120s = importMap(sciezka/"WSe2_mapa_Raman_9_120s.txt")
rs_Raman_150s, I_Raman_150s = importMap(sciezka/"WSe2_mapa_Raman_9_150s.txt")
rs_Raman_180s, I_Raman_180s = importMap(sciezka/"WSe2_mapa_Raman_9_180s.txt")
rs_Raman_210s, I_Raman_210s = importMap(sciezka/"WSe2_mapa_Raman_9_210s.txt")
rs_Raman_240s, I_Raman_240s = importMap(sciezka/"WSe2_mapa_Raman_9_240s.txt")
rs_Raman_270s, I_Raman_270s = importMap(sciezka/"WSe2_mapa_Raman_9_270s.txt")
rs_Raman_300s, I_Raman_300s = importMap(sciezka/"WSe2_mapa_Raman_9_300s.txt")

# %%
#testowe pojedyncze widma PL, żebym wiedziała co dopasować 

plt.plot(rs_PL_0s[10], I_PL_0s[10], label="t=0s", color="#808080")
plt.plot(rs_PL_30s[10], I_PL_30s[12], label="t=30s", color="#89D1D1")
plt.plot(rs_PL_60s[12], I_PL_60s[12], label="t=60s", color="#38AAAA")
plt.plot(rs_PL_90s[10], I_PL_90s[12], label="t=90s", color="#125D76")
plt.plot(rs_PL_120s[12], I_PL_120s[12], label="t=120s", color="#10A3EC")
plt.plot(rs_PL_150s[10], I_PL_150s[10], label="t=150s", color="#445DB6")
plt.plot(rs_PL_180s[10], I_PL_180s[12], label="t=180s", color="#183393")
plt.plot(rs_PL_210s[7], I_PL_210s[7], label="t=210s", color="#9BACED")
plt.plot(rs_PL_240s[9], I_PL_240s[9], label="t=240s", color="#6080F2")
plt.plot(rs_PL_270s[12], I_PL_270s[12], label="t=270s", color="#304CEE")
plt.plot(rs_PL_300s[8], I_PL_300s[8], label="t=300s", color="#0D1B4C")

plt.xlabel(r"E (eV)")
plt.ylabel("Intensity (a.u.)")
plt.legend()

# %%
# testowe pojedyncze widma ramana, żebym wiedziała co dopasować 
plt.plot(rs_Raman_0s[10], I_Raman_0s[10],label="t=0s", color="#808080")
plt.plot(rs_Raman_30s[10], I_Raman_30s[12],label="t=30s", color="#89D1D1")
plt.plot(rs_Raman_60s[12], I_Raman_60s[12],label="t=60s", color="#38AAAA")
plt.plot(rs_Raman_90s[10], I_Raman_90s[12],label="t=90s", color="#125D76")
plt.plot(rs_Raman_120s[12], I_Raman_120s[12],label="t=120s", color="#10A3EC")
plt.plot(rs_Raman_150s[3], I_Raman_150s[3],label="t=150s", color="#445DB6")
plt.plot(rs_Raman_180s[10], I_Raman_180s[12],label="t=180s", color="#183393")
plt.plot(rs_Raman_210s[12], I_Raman_210s[12],label="t=210s", color="#9BACED")
plt.plot(rs_Raman_240s[10], I_Raman_240s[12],label="t=240s", color="#6080F2")
plt.plot(rs_Raman_270s[12], I_Raman_270s[12],label="t=270s", color="#304CEE")
plt.plot(rs_Raman_300s[10], I_Raman_300s[3],label="t=300s", color="#0D1B4C")
plt.xlabel(r"Ramanshift (cm$^{-1}$)")
plt.ylabel("Intensity (a.u.)")
plt.legend()

# %%
#dopasowanie piku PL

centers_PL_0s, fwhms_PL_0s, intensities_PL_0s = lorentz2map(rs_PL_0s, I_PL_0s, xmin=1.5, xmax=1.7)
centers_PL_30s, fwhms_PL_30s, intensities_PL_30s = lorentz2map(rs_PL_30s, I_PL_30s, xmin=1.55, xmax=1.75)
centers_PL_60s, fwhms_PL_60s, intensities_PL_60s = lorentz2map(rs_PL_60s, I_PL_60s, xmin=1.55, xmax=1.75)
centers_PL_90s, fwhms_PL_90s, intensities_PL_90s = lorentz2map(rs_PL_90s, I_PL_90s, xmin=1.55, xmax=1.75)
centers_PL_120s, fwhms_PL_120s, intensities_PL_120s = lorentz2map(rs_PL_120s, I_PL_120s, xmin=1.55, xmax=1.75)
centers_PL_150s, fwhms_PL_150s, intensities_PL_150s = lorentz2map(rs_PL_150s, I_PL_150s, xmin=1.55, xmax=1.75)
centers_PL_180s, fwhms_PL_180s, intensities_PL_180s = lorentz2map(rs_PL_180s, I_PL_180s, xmin=1.55, xmax=1.75)
centers_PL_210s, fwhms_PL_210s, intensities_PL_210s = lorentz2map(rs_PL_210s, I_PL_210s, xmin=1.55, xmax=1.75)
centers_PL_240s, fwhms_PL_240s, intensities_PL_240s = lorentz2map(rs_PL_240s, I_PL_240s, xmin=1.55, xmax=1.75)
centers_PL_270s, fwhms_PL_270s, intensities_PL_270s = lorentz2map(rs_PL_270s, I_PL_270s, xmin=1.55, xmax=1.75)
centers_PL_300s, fwhms_PL_300s, intensities_PL_300s = lorentz2map(rs_PL_300s, I_PL_300s, xmin=1.55, xmax=1.75)

# %%
#dopasowanie piku E i A

centers_Raman_EA_0s, fwhms_Raman_EA_0s, intensities_Raman_EA_0s = lorentz2map(rs_Raman_0s, I_Raman_0s, xmin=240, xmax=255)
centers_Raman_EA_30s, fwhms_Raman_EA_30s, intensities_Raman_EA_30s = lorentz2map(rs_Raman_30s, I_Raman_30s, xmin=240, xmax=255)
centers_Raman_EA_60s, fwhms_Raman_EA_60s, intensities_Raman_EA_60s = lorentz2map(rs_Raman_60s, I_Raman_60s, xmin=240, xmax=255)
centers_Raman_EA_90s, fwhms_Raman_EA_90s, intensities_Raman_EA_90s = lorentz2map(rs_Raman_90s, I_Raman_90s,xmin=240, xmax=255)
centers_Raman_EA_120s, fwhms_Raman_EA_120s, intensities_Raman_EA_120s = lorentz2map(rs_Raman_120s, I_Raman_120s,xmin=240, xmax=255)
centers_Raman_EA_150s, fwhms_Raman_EA_150s, intensities_Raman_EA_150s = lorentz2map(rs_Raman_150s, I_Raman_150s,xmin=240, xmax=255)
centers_Raman_EA_180s, fwhms_Raman_EA_180s, intensities_Raman_EA_180s = lorentz2map(rs_Raman_180s, I_Raman_180s, xmin=240, xmax=255)
centers_Raman_EA_210s, fwhms_Raman_EA_210s, intensities_Raman_EA_210s = lorentz2map(rs_Raman_210s, I_Raman_210s, xmin=240, xmax=255)
centers_Raman_EA_240s, fwhms_Raman_EA_240s, intensities_Raman_EA_240s = lorentz2map(rs_Raman_240s, I_Raman_240s,xmin=240, xmax=255)
centers_Raman_EA_270s, fwhms_Raman_EA_270s, intensities_Raman_EA_270s = lorentz2map(rs_Raman_270s, I_Raman_270s,xmin=240, xmax=255)
centers_Raman_EA_300s, fwhms_Raman_EA_300s, intensities_Raman_EA_300s = lorentz2map(rs_Raman_300s, I_Raman_300s,xmin=240, xmax=255)

# %%
#dopasowanie piku 2LA(M)
centers_Raman_LA_0s, fwhms_Raman_LA_0s, intensities_Raman_LA_0s = lorentz2map(rs_Raman_0s, I_Raman_0s, xmin=255, xmax=265)
centers_Raman_LA_30s, fwhms_Raman_LA_30s, intensities_Raman_LA_30s = lorentz2map(rs_Raman_30s, I_Raman_30s, xmin=255, xmax=265)
centers_Raman_LA_60s, fwhms_Raman_LA_60s, intensities_Raman_LA_60s = lorentz2map(rs_Raman_60s, I_Raman_60s, xmin=255, xmax=265)
centers_Raman_LA_90s, fwhms_Raman_LA_90s, intensities_Raman_LA_90s = lorentz2map(rs_Raman_90s, I_Raman_90s,xmin=255, xmax=265)
centers_Raman_LA_120s, fwhms_Raman_LA_120s, intensities_Raman_LA_120s = lorentz2map(rs_Raman_120s, I_Raman_120s,xmin=255, xmax=265)
centers_Raman_LA_150s, fwhms_Raman_LA_150s, intensities_Raman_LA_150s = lorentz2map(rs_Raman_150s, I_Raman_150s,xmin=255, xmax=265)
centers_Raman_LA_180s, fwhms_Raman_LA_180s, intensities_Raman_LA_180s = lorentz2map(rs_Raman_180s, I_Raman_180s,xmin=255, xmax=265)
centers_Raman_LA_210s, fwhms_Raman_LA_210s, intensities_Raman_LA_210s = lorentz2map(rs_Raman_210s, I_Raman_210s,xmin=255, xmax=265)
centers_Raman_LA_240s, fwhms_Raman_LA_240s, intensities_Raman_LA_240s = lorentz2map(rs_Raman_240s, I_Raman_240s,xmin=255, xmax=265)
centers_Raman_LA_270s, fwhms_Raman_LA_270s, intensities_Raman_LA_270s = lorentz2map(rs_Raman_270s, I_Raman_270s,xmin=255, xmax=265)
centers_Raman_LA_300s, fwhms_Raman_LA_300s, intensities_Raman_LA_300s = lorentz2map(rs_Raman_300s, I_Raman_300s,xmin=255, xmax=265)

# %%
#ręczne usunięcie punktów odbiegających
print(intensities_PL_0s)
#pojedyncze odbiegające punkty => być może wynik "złapania" samego podłoża na mapie
intensities_PL_0s = np.delete(intensities_PL_0s, [3, 4])
print(intensities_PL_0s)
# Out:
# [1312.97087921  838.76696631  319.83831276   50.36315125   89.35834813
#  1198.44352737 1061.26101953 1172.00253259 1262.48445826 1036.03839364
#  1056.4918295   932.20678322 1437.11881047 1444.18527446 1037.7028214
#  1181.85637498 1259.88629396 1085.19924444  697.16201317  682.59127301
#   984.59928401 1115.88651897 1252.3477138  1025.21042542  136.43448553]
# [1312.97087921  838.76696631  319.83831276 1198.44352737 1061.26101953
#  1172.00253259 1262.48445826 1036.03839364 1056.4918295   932.20678322
#  1437.11881047 1444.18527446 1037.7028214  1181.85637498 1259.88629396
#  1085.19924444  697.16201317  682.59127301  984.59928401 1115.88651897
#  1252.3477138  1025.21042542  136.43448553]

# %%
print(centers_PL_0s)
# Out:
# [1.65563029 1.65535836 1.65185614 1.65467746 1.64901826 1.65814013
#  1.65546976 1.65788646 1.65896935 1.65435175 1.6595411  1.65512947
#  1.6549254  1.65765169 1.65571369 1.65628873 1.65383381 1.65535506
#  1.6556483  1.65378462 1.6526317  1.65564146 1.65903824 1.65105172
#  1.65474974]

# %%
print(intensities_PL_30s)
#pojedyncze odbiegające punkty 
intensities_PL_30s = np.delete(intensities_PL_30s, [0, 4,8])
print(intensities_PL_30s)
# Out:
# [  76.32355374 2195.9544578  2403.72563488 2645.71258112   36.95104219
#  2268.23741922 1641.41858928 2413.77051243   39.30643439 2180.76148931
#  2418.19131413 2588.80342202  366.2006384  2211.82595016 2529.89414672
#  3591.11010899 2141.40548474 2026.23556222 2236.84418035 2253.53382662]
# [2195.9544578  2403.72563488 2645.71258112 2268.23741922 1641.41858928
#  2413.77051243 2180.76148931 2418.19131413 2588.80342202  366.2006384
#  2211.82595016 2529.89414672 3591.11010899 2141.40548474 2026.23556222
#  2236.84418035 2253.53382662]

# %%
print(intensities_PL_60s)
#pojedyncze odbiegające punkty 
intensities_PL_60s = np.delete(intensities_PL_60s, [0,5])
print(intensities_PL_60s)
# Out:
# [ 122.91827333 3090.51180233 3389.8711879  2118.93907046 3878.22899407
#   266.82134846 3560.14955448 3522.34195346 3307.114573   3748.91870308
#   738.78610288 3009.34557836 3335.64764262 3680.77709844 4854.22381325
#  2950.08636264 3815.46171261 3674.15553133 2192.04306635 3354.48373075]
# [3090.51180233 3389.8711879  2118.93907046 3878.22899407 3560.14955448
#  3522.34195346 3307.114573   3748.91870308  738.78610288 3009.34557836
#  3335.64764262 3680.77709844 4854.22381325 2950.08636264 3815.46171261
#  3674.15553133 2192.04306635 3354.48373075]

# %%
print(intensities_PL_90s)
print(intensities_PL_120s)

print(intensities_PL_150s)
#pojedyncze odbiegające punkty 
#intensities_PL_150s = np.delete(intensities_PL_150s, [0,10])
#print(intensities_PL_150s)
# Out:
# [2393.16544249 4478.07765358 4256.99489406 4690.95818498 4415.00845315
#   722.17113277 3833.56276937 3985.90484753 5205.89770883 2837.12670395
#  3418.50192715 4930.00695174 5245.1195671  6400.00613408 5214.87104062
#  3789.21248447 3457.17273821 4314.39270041 5464.79957365 5073.83162651]
# [4357.9368573  5964.60089739 6133.83213269 6884.94010624 5847.54602919
#  2964.60142561 6695.59843934 5812.52580611 6591.29543426 4756.55885205
#  5388.53911872 6988.82597565 7417.49272734 7546.23295997 6354.44259969
#  5056.69891704 6302.41640675 6123.74948863 3691.38785234 6836.64610768]
# [ 511.93304078 5870.69265161 6605.96329828 7452.15592261 7414.02552251
#  1776.93830488 8315.10614924 6736.86583637 8579.93942269 6866.11481541
#   477.21886296 5402.78446854 7751.87422951 8474.70773877 9927.28441411
#  2399.40786975 7503.97038685 8172.7392493  8866.60835532 7461.59449152]

# %%
print(intensities_PL_180s)
#pojedyncze odbiegające punkty 
intensities_PL_180s = np.delete(intensities_PL_180s, [0,10])
print(intensities_PL_180s)
# Out:
# [ 240.36130154 5392.12638296 6199.66323693 6273.49419008 8828.78633318
#   500.90974727 7713.14709441 8600.39206517 8553.77513887 9080.59173697
#   296.59748542 3058.84025025 9331.85200112 9462.39188646 8738.34297605
#  1188.88735472 8905.58983905 8918.10966927 9496.85559216 9168.63954216]
# [5392.12638296 6199.66323693 6273.49419008 8828.78633318  500.90974727
#  7713.14709441 8600.39206517 8553.77513887 9080.59173697 3058.84025025
#  9331.85200112 9462.39188646 8738.34297605 1188.88735472 8905.58983905
#  8918.10966927 9496.85559216 9168.63954216]

# %%
print(intensities_PL_210s)
#pojedyncze odbiegające punkty 
#intensities_PL_210s = np.delete(intensities_PL_210s, [0])
#print(intensities_PL_210s)
# Out:
# [  938.25008796  7439.38720759  7580.48846355  8919.77907314
#   2274.42276455  8435.2070419   8445.06871715 10298.46985333
#   3492.30724692  9174.87431087  9366.01848453 10618.78531003
#   1687.99586796 10066.49305884 10398.12764585  9954.28873822
#   8942.19522385 10321.94117141  9721.70109328 10145.19059877]

# %%
print(intensities_PL_240s)
print(intensities_PL_270s)
#pojedyncze odbiegające punkty 
#intensities_PL_270s = np.delete(intensities_PL_270s, [0,4])
#print(intensities_PL_270s)
# Out:
# [ 2845.61883912  7785.37031002  7495.23664628  8749.0511585
#   8306.7086983   9318.0733955   7693.4231313  10241.91893916
#   5998.0207866  10804.2837501  10882.13694743  9461.65807462
#   9315.09407383 10054.4767051   9683.40538701 11189.92998805
#   9691.97647108  9634.56470216 10727.33386812 10985.27556732]
# [  600.82592025  2703.6744686   9647.46679356  9518.39008703
#    537.92623633  9301.03186471 11901.1260172  11341.24523629
#   1621.4421904   8200.39234601 12814.07913376 12934.98040377
#   6417.15856557 11792.37916762 11768.45338561 12198.02282409
#   7172.02993332  9453.79501642 10503.49445442 10603.20439515]

# %%
print(intensities_PL_300s)
# Out:
# [  103.80698139  2595.08846357  8184.27119097  8607.72095303
#   9845.98429152   539.99643102  7292.79922812 10256.57788339
#   9033.78129613 11501.71516664   220.80364039  3977.44764108
#  12087.83214624 12077.60034158 10097.39208604  1102.27400684
#  11513.39237343 11758.4881456  11996.74225815 11961.23345379]

# %%
intensity_PL_mean_9=[np.mean(intensities_PL_0s),np.mean(intensities_PL_30s),np.mean(intensities_PL_60s),np.mean(intensities_PL_90s),np.mean(intensities_PL_120s),np.mean(intensities_PL_150s),np.mean(intensities_PL_180s),np.mean(intensities_PL_210s),np.mean(intensities_PL_240s),np.mean(intensities_PL_270s),np.mean(intensities_PL_300s)]
centers_PL_mean_9=[np.mean(centers_PL_0s),np.mean(centers_PL_30s),np.mean(centers_PL_60s),np.mean(centers_PL_90s),np.mean(centers_PL_120s),np.mean(centers_PL_150s),np.mean(centers_PL_180s),np.mean(centers_PL_210s),np.mean(centers_PL_240s),np.mean(centers_PL_270s),np.mean(centers_PL_300s)]
fwhms_PL_mean_9=[np.mean(fwhms_PL_0s),np.mean(fwhms_PL_30s),np.mean(fwhms_PL_60s),np.mean(fwhms_PL_90s),np.mean(fwhms_PL_120s),np.mean(fwhms_PL_150s),np.mean(fwhms_PL_180s),np.mean(fwhms_PL_210s),np.mean(fwhms_PL_240s),np.mean(fwhms_PL_270s),np.mean(fwhms_PL_300s)]

intensity_Raman_E_mean_9=[np.mean(intensities_Raman_E_0s),np.mean(intensities_Raman_E_30s),np.mean(intensities_Raman_E_60s),np.mean(intensities_Raman_E_90s),np.mean(intensities_Raman_E_120s),np.mean(intensities_Raman_E_150s),np.mean(intensities_Raman_E_180s),np.mean(intensities_Raman_E_210s),np.mean(intensities_Raman_E_240s),np.mean(intensities_Raman_E_270s),np.mean(intensities_Raman_E_300s)]
centers_Raman_E_mean_9=[np.mean(centers_Raman_E_0s),np.mean(centers_Raman_E_30s),np.mean(centers_Raman_E_60s),np.mean(centers_Raman_E_90s),np.mean(centers_Raman_E_120s),np.mean(centers_Raman_E_150s),np.mean(centers_Raman_E_180s),np.mean(centers_Raman_E_210s),np.mean(centers_Raman_E_240s),np.mean(centers_Raman_E_270s),np.mean(centers_Raman_E_300s)]
#fwhms_Raman_E_mean_8=[np.mean(fwhms_Raman_E_0s),np.mean(fwhms_Raman_E_2s),np.mean(fwhms_Raman_E_4s),np.mean(fwhms_Raman_E_6s),np.mean(fwhms_Raman_E_8s),np.mean(fwhms_Raman_E_10s)]

intensity_Raman_A_mean_9=[np.mean(intensities_Raman_A_0s),np.mean(intensities_Raman_A_30s),np.mean(intensities_Raman_A_60s),np.mean(intensities_Raman_A_90s),np.mean(intensities_Raman_A_120s),np.mean(intensities_Raman_A_150s),np.mean(intensities_Raman_A_180s),np.mean(intensities_Raman_A_210s),np.mean(intensities_Raman_A_240s),np.mean(intensities_Raman_A_270s),np.mean(intensities_Raman_A_300s)]
centers_Raman_A_mean_9=[np.mean(centers_Raman_A_0s),np.mean(centers_Raman_A_30s),np.mean(centers_Raman_A_60s),np.mean(centers_Raman_A_90s),np.mean(centers_Raman_A_120s),np.mean(centers_Raman_A_150s),np.mean(centers_Raman_A_180s),np.mean(centers_Raman_A_210s),np.mean(centers_Raman_A_240s),np.mean(centers_Raman_A_270s),np.mean(centers_Raman_A_300s)]
#fwhms_Raman_A_mean_8=[np.mean(fwhms_Raman_A_0s),np.mean(fwhms_Raman_A_2s),np.mean(fwhms_Raman_A_4s),np.mean(fwhms_Raman_A_6s),np.mean(fwhms_Raman_A_8s),np.mean(fwhms_Raman_A_10s)]

# %%
print(intensity_PL_mean_9)
# Out:
# [np.float64(1023.0732711307471), np.float64(2241.97795990505), np.float64(3234.5048043353268), np.float64(4206.33912673248), np.float64(5885.793406699254), np.float64(6328.396251549986), np.float64(7189.577502058425), np.float64(7911.0495979843645), np.float64(9043.177871980497), np.float64(8551.555922006091), np.float64(7737.747398946359)]

# %%
print(centers_PL_mean_9)
# Out:
# [np.float64(1.6552937072589338), np.float64(1.6546471823203295), np.float64(1.6549147026889153), np.float64(1.654048524786641), np.float64(1.6549240790689062), np.float64(1.6559145427839321), np.float64(1.6560399966086343), np.float64(1.6563852468012068), np.float64(1.6564237460833506), np.float64(1.6574469792360922), np.float64(1.6572816152128589)]

# %%
print(fwhms_PL_mean_9)
# Out:
# [np.float64(0.05843717527540348), np.float64(0.052590896049938274), np.float64(0.04878728444446172), np.float64(0.04813319273593033), np.float64(0.04479309016780473), np.float64(0.04438116644966639), np.float64(0.04460216593982495), np.float64(0.043852591576979384), np.float64(0.04318122116835495), np.float64(0.043060444035922595), np.float64(0.04363700679311995)]

# %%
print(centers_Raman_E_mean_9)
# Out:
# [np.float64(249.95950407153504), np.float64(250.0710137768388), np.float64(249.84664889235233), np.float64(250.31804604089248), np.float64(249.8927045892861), np.float64(249.76138135395823), np.float64(249.87362935968486), np.float64(249.63069036093256), np.float64(249.89767982065104), np.float64(248.99797609078524), np.float64(249.93697599051262)]

# %%
sciezka = BASE / "analiza" / "próbka9" / "wykresy"
time=[0,30,60,90,120,150,180,210,240,270,300]
plt.scatter(time,intensity_PL_mean_9,label="próbka 9")
plt.legend()
plt.xlabel(r"t (s)")
plt.ylabel("Mean instensity (a.u)")
plt.savefig(sciezka/'zaleznosc_I_PL_od_t.png')
#bardzo niejednorodne dla wyższych czasów defektowania

# %%
time=[0,30,60,90,120,150,180,210,240,270,300]
plt.scatter(time,centers_PL_mean_9,label="próbka 9")
plt.legend()
plt.xlabel(r"t (s)")
plt.ylabel("Mean peak position (eV)")
plt.savefig(sciezka/'zaleznosc_x_PL_od_t.png')
#redshift

# %%
time=[0,30,60,90,120,150,180,210,240,270,300]
plt.scatter(time,fwhms_PL_mean_9,label="próbka 9")
plt.legend()
plt.xlabel(r"t (s)")
plt.ylabel("Mean FWHM (eV)")
plt.savefig(sciezka/'zaleznosc_fwhm_PL_od_t.png')
#redshift

# %%
x = np.linspace(1.45,1.85, 500)
time=[0,30,60,90,120,150,180,210,240,270,300]

for t, c, f, h in zip(time, centers_PL_mean_9, fwhms_PL_mean_9, intensity_PL_mean_9):
    #jeśli się nie dopasowało to fit zwraca nan, pozbywamy się ich 
    mask = ~np.isnan(c) & ~np.isnan(f) & ~np.isnan(h)
    c0 = np.mean(np.array(c)[mask])
    f0 = np.mean(np.array(f)[mask])
    h0 = np.mean(np.array(h)[mask])
    y = lorentz(x, h0, c0, f0)
    plt.plot(x, y, label=f"t={t}s")

plt.xlabel("E (eV)")
plt.ylabel("Intensity (a.u.)")
plt.xlim(1.45, 1.85)
plt.legend()
plt.savefig(sciezka/'usrednione_PL.png')

# %%
time = [0,30,60,90,120,150,180,210,240,270,300]
time = np.array(time)
intensity_E = np.array(intensity_Raman_E_mean_9)
intensity_A = np.array(intensity_Raman_A_mean_9)
centers_E = np.array(centers_Raman_E_mean_9)
centers_A = np.array(centers_Raman_A_mean_9)

prog_E = 0.1 * np.max(intensity_E)
prog_A = 0.1 * np.max(intensity_A)

mask_E = intensity_E > prog_E
mask_A = intensity_A > prog_A

plt.scatter(time[mask_E], intensity_E[mask_E], label="pik E$^1_{2g}$")
plt.scatter(time[mask_A], intensity_A[mask_A], label="pik LA(M)")
plt.xlabel(r"t (s)")
plt.ylabel("Mean peak intensity (cm$^{-1}$)")
plt.legend()
plt.savefig(sciezka/'zaleznosc_I_Raman_A_od_t.png')

# %%
time = [0,30,60,90,120,150,180,210,240,270,300]
time = np.array(time)

plt.scatter(time,centers_E, label="pik E$^1_{2g}$")
plt.scatter(time, centers_A, label="pik LA(M)")
plt.xlabel(r"t (s)")
plt.ylabel("Mean peak position (cm$^{-1}$)")
plt.legend()
plt.savefig(sciezka/'zaleznosc_x_Raman_A_od_t.png')
